# %% [markdown]
# <h2 align='center'>NLP Tutorial: Text Representation - Bag Of Words (BOW)</h2>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("spam.csv")
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.Category.value_counts()
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df['spam'] = df['Category'].apply(lambda x: 1 if x =='spam' else 0)

# %%
df.shape
# Out:
# (5572, 3)

# %%
df.head()
# Out:
#   Category                                            Message  spam
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0

# %% [markdown]
# <h3>Train test split</h3>

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.Message, df.spam, test_size=0.2)

# %%
X_train.shape
# Out:
# (4457,)

# %%
X_test.shape
# Out:
# (1115,)

# %%
type(X_train)
# Out:
# pandas.Series

# %%
X_train[:4]
# Out:
# 2392                          PICK UR FONE UP NOW U DUMB?
# 3644    Sorry, left phone upstairs. OK, might be hecti...
# 2587    If you don't respond imma assume you're still ...
# 4140    Ever green quote ever told by Jerry in cartoon...
# Name: Message, dtype: str

# %%
type(y_train)
# Out:
# pandas.Series

# %%
y_train[:4]
# Out:
# 2392    0
# 3644    0
# 2587    0
# 4140    0
# Name: spam, dtype: int64

# %%
type(X_train.values)
# Out:
# pandas.arrays.StringArray

# %% [markdown]
# <h3>Create bag of words representation using CountVectorizer</h3>

# %%
from sklearn.feature_extraction.text import CountVectorizer

v = CountVectorizer()

X_train_cv = v.fit_transform(X_train.values)
X_train_cv
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 59585 stored elements and shape (4457, 7738)>

# %%
# To convert it to an array
X_train_cv.toarray()[:2][0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(7738,))

# %%
X_train_cv.shape
# Out:
# (4457, 7738)

# %%
# To see entire vocabulary
v.get_feature_names_out()
# Out:
# array(['00', '000', '000pes', ..., 'zyada', 'èn', '〨ud'],
#       shape=(7738,), dtype=object)

# %%
#each word in vocabulary with its index position
v.vocabulary_
# Out:
# {'pick': 5204,
#  'ur': 7197,
#  'fone': 2913,
#  'up': 7181,
#  'now': 4844,
#  'dumb': 2479,
#  'sorry': 6335,
#  'left': 4064,
#  'phone': 5190,
#  'upstairs': 7195,
#  'ok': 4918,
#  'might': 4473,
#  'be': 1274,
#  'hectic': 3385,
#  'but': 1575,
#  'would': 7607,
#  'all': 907,
#  'my': 4665,
#  'birds': 1369,
#  'with': 7546,
#  'one': 4940,
#  'fell': 2797,
#  'swoop': 6657,
#  'it': 3752,
#  'date': 2166,
#  'if': 3595,
#  'you': 7702,
#  'don': 2404,
#  'respond': 5734,
#  'imma': 3618,
#  'assume': 1110,
#  're': 5580,
#  'still': 6482,
#  'asleep': 1102,
#  'and': 953,
#  'start': 6446,
#  'calling': 1618,
#  'shit': 6094,
#  'ever': 2654,
#  'green': 3235,
#  'quote': 5531,
#  'told': 6941,
#  'by': 1590,
#  'jerry': 3812,
#  'in': 3634,
#  'cartoon': 1671,
#  'person': 5166,
#  'who': 7491,
#  'irritates': 3738,
#  'always': 927,
#  'is': 3742,
#  'the': 6806,
#  'loves': 4233,
#  'vry': 7326,
#  'much': 4633,
#  'fails': 2741,
#  'to': 6924,
#  'express': 2717,
#  'gud': 3262,
#  'nyt': 4876,
#  'carlos': 1662,
#  'says': 5920,
#  'he': 3364,
#  'll': 4156,
#  'at': 1119,
#  'mu': 4631,
#  'lt': 4248,
#  'gt': 3256,
#  'minutes': 4500,
#  'career': 1654,
#  'tel': 6744,
#  'have': 3354,
#  'added': 805,
#  'as': 1086,
#  'contact': 1972,
#  'on': 4934,
#  'indyarocks': 3661,
#  'com': 1895,
#  'send': 6003,
#  'free': 2973,
#  'sms': 6262,
#  'remove': 5686,
#  'from': 3008,
#  'phonebook': 5192,
#  'no': 4797,
#  'fine': 2842,
#  'hope': 3482,
#  'are': 1048,
#  'also': 921,
#  'thing': 6834,
#  'good': 3177,
#  'thanx': 6801,
#  'got': 3195,
#  'exams': 2682,
#  'march': 4356,
#  'ive': 3764,
#  'done': 2406,
#  'revision': 5759,
#  'fran': 2962,
#  'boyf': 1472,
#  'gotta': 3201,
#  'interviw': 3708,
#  'exeter': 2693,
#  'bit': 1374,
#  'worried': 7597,
#  'honeybee': 3473,
#  'said': 5873,
#  'sweetest': 6646,
#  'world': 7594,
#  'god': 3160,
#  'laughed': 4033,
#  'amp': 942,
#  'wait': 7347,
#  'havnt': 3362,
#  'met': 4463,
#  'reading': 5590,
#  'this': 6844,
#  'msg': 4616,
#  'moral': 4582,
#  'even': 2648,
#  'can': 1628,
#  'crack': 2045,
#  'jokes': 3840,
#  'gm': 3149,
#  'gn': 3151,
#  'ge': 3087,
#  'ready': 5591,
#  'am': 929,
#  'escape': 2629,
#  'theatre': 6809,
#  'going': 3167,
#  'watch': 7393,
#  'kavalan': 3898,
#  'few': 2806,
#  'hey': 3417,
#  'we': 7413,
#  'go': 3154,
#  'jazz': 3798,
#  'power': 5350,
#  'yoga': 7698,
#  'hip': 3435,
#  'hop': 3481,
#  'kb': 3901,
#  'yogasana': 7699,
#  'ya': 7662,
#  'cant': 1639,
#  'display': 2358,
#  'internal': 3704,
#  'subs': 6557,
#  'so': 6283,
#  'extract': 2722,
#  'them': 6812,
#  'get': 3108,
#  'wanna': 7370,
#  'chat': 1739,
#  'set': 6027,
#  'meet': 4425,
#  'call': 1606,
#  'me': 4407,
#  '09096102316': 252,
#  'cum': 2105,
#  'here': 3408,
#  '2moro': 401,
#  'luv': 4264,
#  'jane': 3786,
#  'xx': 7650,
#  'calls': 1620,
#  'minmoremobsemspobox45po139wa': 4495,
#  'watching': 7397,
#  'tv': 7080,
#  'lor': 4203,
#  'she': 6071,
#  'funny': 3037,
#  'bluff': 1411,
#  'her': 3407,
#  'wat': 7392,
#  'izzit': 3769,
#  'because': 1283,
#  'thk': 6845,
#  'impossible': 3627,
#  'between': 1339,
#  'us': 7209,
#  'entry': 2606,
#  'weekly': 7438,
#  'comp': 1915,
#  'for': 2926,
#  'chance': 1719,
#  'win': 7518,
#  'an': 948,
#  'ipod': 3731,
#  'txt': 7091,
#  'pod': 5284,
#  '80182': 641,
#  'std': 6463,
#  'rate': 5564,
#  'apply': 1022,
#  '08452810073': 68,
#  'details': 2274,
#  '18': 327,
#  'big': 1354,
#  'brother': 1526,
#  'really': 5600,
#  'scraped': 5943,
#  'barrel': 1236,
#  'shower': 6126,
#  'of': 4892,
#  'social': 6286,
#  'misfits': 4506,
#  'buzy': 1583,
#  'gr8': 3208,
#  'new': 4759,
#  'service': 6023,
#  'live': 4148,
#  'sex': 6035,
#  'video': 7279,
#  'your': 7706,
#  'mob': 4541,
#  'see': 5977,
#  'sexiest': 6036,
#  'dirtiest': 2337,
#  'girls': 3134,
#  'text': 6779,
#  'horny': 3491,
#  '89070': 706,
#  'cancel': 1632,
#  'stop': 6494,
#  'miss': 4509,
#  'khelate': 3921,
#  'kintu': 3942,
#  'opponenter': 4967,
#  'dhorte': 2288,
#  'lage': 3996,
#  'thats': 6805,
#  'rule': 5845,
#  'great': 3231,
#  'receiving': 5619,
#  'quality': 5514,
#  'wins': 7532,
#  'hard': 3331,
#  'true': 7046,
#  'how': 3515,
#  'show': 6125,
#  'love': 4225,
#  'someone': 6302,
#  'that': 6802,
#  'will': 7515,
#  'hurt': 3554,
#  'when': 7477,
#  'they': 6829,
#  'leave': 4058,
#  'or': 4977,
#  'seperated': 6016,
#  '〨ud': 7737,
#  'evening': 2649,
#  'jokin': 3841,
#  'oni': 4942,
#  'lar': 4016,
#  'busy': 1574,
#  'then': 6816,
#  'wun': 7636,
#  'disturb': 2360,
#  'well': 7450,
#  'bbd': 1259,
#  'pooja': 5305,
#  'full': 3027,
#  'pimples': 5220,
#  'become': 1285,
#  'quite': 5526,
#  'black': 1382,
#  'rite': 5789,
#  'its': 3758,
#  'too': 6964,
#  'cold': 1882,
#  'wearing': 7418,
#  'sweatter': 6644,
#  'hr': 3523,
#  'want': 7372,
#  'posting': 5338,
#  'chennai': 1762,
#  'working': 7591,
#  'not': 4832,
#  'sure': 6618,
#  'stomach': 6488,
#  'know': 3956,
#  'thinkin': 6838,
#  'malaria': 4330,
#  'relax': 5667,
#  'children': 1781,
#  'handle': 3308,
#  'been': 1294,
#  'worse': 7600,
#  'gastroenteritis': 3072,
#  'takes': 6688,
#  'enough': 2593,
#  'replace': 5702,
#  'loss': 4209,
#  'temp': 6755,
#  'reduce': 5641,
#  'give': 3137,
#  'meds': 4423,
#  'just': 3871,
#  'vomit': 7318,
#  'self': 5992,
#  'limiting': 4119,
#  'illness': 3609,
#  'has': 3340,
#  'which': 7485,
#  'means': 4414,
#  'days': 2174,
#  'completely': 1927,
#  'valued': 7242,
#  'customer': 2119,
#  'pleased': 5255,
#  'advise': 833,
#  'following': 2909,
#  'recent': 5620,
#  'review': 5758,
#  'awarded': 1172,
#  '1500': 311,
#  'bonus': 1425,
#  'prize': 5419,
#  '09066364589': 236,
#  'found': 2954,
#  'diff': 2308,
#  'farm': 2764,
#  'shop': 6106,
#  'buy': 1579,
#  'some': 6298,
#  'cheese': 1760,
#  'way': 7408,
#  'back': 1196,
#  'sunday': 6596,
#  'where': 7481,
#  'meeting': 4427,
#  'babe': 1188,
#  'goes': 3162,
#  'day': 2173,
#  'what': 7470,
#  'already': 918,
#  'loving': 4235,
#  'kiss': 3945,
#  'everything': 2663,
#  'further': 3040,
#  'club': 1849,
#  'tones': 6954,
#  'replying': 5708,
#  'mix': 4524,
#  'tone': 6953,
#  'enjoy': 2586,
#  'html': 3527,
#  'terms': 6765,
#  'cost': 2015,
#  'gbp4': 3083,
#  '50': 534,
#  'week': 7435,
#  'mfl': 4465,
#  'po': 5268,
#  'box': 1455,
#  '1146': 279,
#  'mk45': 4528,
#  '2wt': 421,
#  'asked': 1097,
#  'him': 3431,
#  'tell': 6748,
#  'bad': 1198,
#  'character': 1727,
#  'dnt': 2373,
#  'lik': 4108,
#  'try': 7053,
#  'change': 1721,
#  'add': 803,
#  'tat': 6710,
#  'year': 7677,
#  'resolution': 5729,
#  'waiting': 7350,
#  'reply': 5707,
#  'frank': 2963,
#  'morning': 4587,
#  'his': 3437,
#  'friend': 2994,
#  'money': 4569,
#  'definitely': 2219,
#  'buying': 1581,
#  'before': 1300,
#  'end': 2571,
#  'dad': 2136,
#  'gonna': 3175,
#  'after': 848,
#  'gets': 3112,
#  'out': 5013,
#  'work': 7588,
#  'ask': 1095,
#  'these': 6824,
#  'crazy': 2055,
#  'questions': 5521,
#  'ex': 2678,
#  'wife': 7506,
#  'was': 7385,
#  'able': 751,
#  'kids': 3929,
#  'do': 2374,
#  'yup': 7726,
#  'elaborating': 2548,
#  'safety': 5872,
#  'aspects': 1103,
#  'other': 5003,
#  'issues': 3751,
#  'staff': 6428,
#  'science': 5932,
#  'nus': 4865,
#  'edu': 2522,
#  'sg': 6043,
#  'phyhcmk': 5200,
#  'teaching': 6730,
#  'pc1323': 5128,
#  'noon': 4815,
#  'sarcasm': 5896,
#  'nt': 4851,
#  'scarcasim': 5924,
#  'yunny': 7723,
#  'walking': 7358,
#  'citylink': 1814,
#  'faster': 2768,
#  'come': 1901,
#  'down': 2421,
#  'very': 7269,
#  'hungry': 3546,
#  'office': 4903,
#  'may': 4398,
#  'wonder': 7574,
#  'why': 7499,
#  'smiling': 6254,
#  'sore': 6332,
#  'grocers': 3244,
#  'im': 3611,
#  'gonnamissu': 3176,
#  'say': 5916,
#  'il': 3606,
#  'postcard': 5335,
#  'buttheres': 1577,
#  'aboutas': 754,
#  'merememberin': 4453,
#  'asthere': 1112,
#  'ofsi': 4909,
#  'breakin': 1492,
#  'contract': 1983,
#  'yaxx': 7672,
#  'dont': 2408,
#  'let': 4082,
#  'studying': 6540,
#  'stress': 6516,
#  'l8r': 3981,
#  'house': 3510,
#  'entertaining': 2599,
#  'getting': 3116,
#  'whole': 7493,
#  'hugh': 3534,
#  'laurie': 4037,
#  'stick': 6478,
#  'indeed': 3653,
#  'especially': 2633,
#  'horrible': 3493,
#  'eat': 2509,
#  'macs': 4297,
#  'until': 7180,
#  'forgot': 2939,
#  'abt': 759,
#  'take': 6685,
#  'long': 4189,
#  'more': 4583,
#  'toot': 6969,
#  'than': 6792,
#  'b4': 1182,
#  'prepared': 5384,
#  'shall': 6056,
#  'reach': 5581,
#  'ten': 6758,
#  'same': 5887,
#  'wrong': 7622,
#  'everyso': 2661,
#  'often': 4911,
#  'panicks': 5069,
#  'starts': 6449,
#  'goin': 3165,
#  'bout': 1452,
#  'bein': 1311,
#  'help': 3397,
#  'sleeping': 6215,
#  'surfing': 6620,
#  'ew': 2677,
#  'born': 1442,
#  'oh': 4913,
#  'another': 975,
#  'idiot': 3590,
#  'were': 7459,
#  'competition': 1921,
#  'knew': 3953,
#  'two': 7090,
#  'freinds': 2982,
#  'forever': 2931,
#  'pa': 5050,
#  'home': 3467,
#  'within': 7548,
#  'min': 4484,
#  'aight': 875,
#  'roommates': 5815,
#  'gibbs': 3121,
#  'unsold': 7174,
#  'mike': 4475,
#  'hussey': 3558,
#  'every': 2655,
#  'use': 7213,
#  'sleep': 6213,
#  'only': 4946,
#  'thank': 6795,
#  'skyped': 6207,
#  'wit': 7545,
#  'kz': 3979,
#  'sura': 6617,
#  'didnt': 2301,
#  'pleasure': 5257,
#  'company': 1917,
#  've': 7256,
#  'given': 3138,
#  'ultimatum': 7121,
#  'countin': 2026,
#  'aburo': 761,
#  'yes': 7685,
#  'trust': 7050,
#  'stuff': 6542,
#  'asap': 1087,
#  'weirdest': 7445,
#  'auto': 1152,
#  'correct': 2009,
#  'yeah': 7676,
#  'class': 1822,
#  'er': 2615,
#  'enjoyin': 2588,
#  'indians': 3658,
#  'mo': 4539,
#  'yep': 7683,
#  'sall': 5881,
#  'hehe': 3388,
#  'hows': 3518,
#  'shexy': 6081,
#  'pete': 5175,
#  'prob': 5422,
#  'sir': 6180,
#  'had': 3288,
#  'weekend': 7436,
#  'called': 1612,
#  'raise': 5546,
#  'however': 3517,
#  'make': 4325,
#  'rest': 5740,
#  'available': 1157,
#  'mid': 4469,
#  'feb': 2784,
#  'amount': 941,
#  'short': 6111,
#  'hoping': 3489,
#  'abiola': 749,
#  'cheers': 1758,
#  'callin': 1617,
#  'sozi': 6353,
#  'culdnt': 2103,
#  'talkbut': 6694,
#  'wannatell': 7371,
#  'later': 4028,
#  'wenwecan': 7457,
#  'properly': 5458,
#  'time': 6891,
#  'finish': 2845,
#  'holiday': 3462,
#  'monday': 4567,
#  'feeling': 2791,
#  'dentists': 2246,
#  'hour': 3507,
#  'congratulations': 1957,
#  'won': 7572,
#  'winner': 7529,
#  'our': 5010,
#  'august': 1144,
#  '1000': 264,
#  'draw': 2434,
#  '09066660100': 244,
#  'code': 1874,
#  '2309': 367,
#  'ha': 3284,
#  'wouldn': 7609,
#  'didn': 2300,
#  'read': 5587,
#  'anything': 997,
#  'into': 3710,
#  'seemed': 5983,
#  'like': 4109,
#  'judgemental': 3858,
#  'save': 5911,
#  'fridays': 2991,
#  'pub': 5480,
#  'upping': 7192,
#  'order': 4984,
#  'grams': 3215,
#  'nyc': 4874,
#  'audiitions': 1140,
#  'trying': 7055,
#  'relocate': 5672,
#  'workin': 7590,
#  'once': 4938,
#  'job': 3828,
#  'should': 6120,
#  'head': 3365,
#  'straight': 6510,
#  'there': 6822,
#  'alright': 919,
#  'justthought': 3875,
#  'sayhey': 5917,
#  'doin': 2395,
#  'nearly': 4720,
#  'endof': 2575,
#  'wk': 7555,
#  'offdam': 4897,
#  'nevamind': 4755,
#  '2hook': 396,
#  'sn': 6267,
#  'uwant': 7231,
#  'm8': 4282,
#  'lovejen': 4227,
#  'burger': 1564,
#  'yourself': 7710,
#  'move': 4603,
#  'pain': 5058,
#  'killing': 3934,
#  'looks': 4197,
#  'kappa': 3893,
#  'guys': 3277,
#  'numbers': 4861,
#  'around': 1071,
#  'took': 6965,
#  'tablets': 6674,
#  'reaction': 5586,
#  'hi': 3421,
#  'kate': 3895,
#  'lovely': 4228,
#  'tonight': 6959,
#  'ill': 3608,
#  'tomorrow': 6951,
#  'sing': 6172,
#  'guy': 3276,
#  'gave': 3075,
#  'card': 1648,
#  'xxx': 7653,
#  'princess': 5412,
#  'sentence': 6013,
#  'concentrate': 1938,
#  'educational': 2523,
#  'leaving': 4060,
#  '80488': 643,
#  '500': 535,
#  'messages': 4459,
#  'valid': 7238,
#  '31': 434,
#  'december': 2194,
#  '2005': 355,
#  'think': 6836,
#  'any': 988,
#  'girl': 3131,
#  'propose': 5460,
#  'today': 6931,
#  'seing': 5988,
#  'bloody': 1404,
#  'funky': 3036,
#  'fucking': 3019,
#  'face': 2730,
#  'asssssholeeee': 1109,
#  'sounds': 6345,
#  'better': 1336,
#  'doing': 2396,
#  'costume': 2019,
#  'afternoon': 850,
#  'prospects': 5464,
#  'missing': 4511,
#  'being': 1312,
#  'lazy': 4044,
#  'bleak': 1390,
#  'hmmm': 3448,
#  'happy': 3330,
#  'filled': 2827,
#  'balance': 1209,
#  '600': 569,
#  'next': 4767,
#  'question': 5519,
#  'complete': 1925,
#  'landmark': 4008,
#  'bob': 1417,
#  'barry': 1238,
#  'ben': 1324,
#  '83738': 667,
#  'luck': 4252,
#  'smoke': 6256,
#  'smoked': 6257,
#  'last': 4022,
#  'weeks': 7439,
#  'texting': 6786,
#  'wanted': 7374,
#  'prabha': 5356,
#  'soryda': 6342,
#  'realy': 5601,
#  'frm': 2999,
#  'heart': 3378,
#  'sory': 6341,
#  'boytoy': 1474,
#  'happened': 3323,
#  'wnt': 7564,
#  'tlk': 6912,
#  'wid': 7503,
#  '1st': 342,
#  'str8': 6509,
#  'each': 2494,
#  'nokia': 4806,
#  '8007': 636,
#  'classic': 1824,
#  'hit': 3439,
#  'polys': 5301,
#  '150p': 312,
#  'poly': 5295,
#  '200p': 358,
#  '16': 323,
#  'reason': 5603,
#  'team': 6731,
#  'budget': 1547,
#  'players': 5248,
#  'base': 1240,
#  'garbage': 3065,
#  'bags': 1202,
#  'eggs': 2538,
#  'jam': 3780,
#  'bread': 1488,
#  'hannaford': 3318,
#  'wheat': 7474,
#  'chex': 1767,
#  'mila': 4476,
#  'age23': 860,
#  'blonde': 1402,
#  'uk': 7117,
#  'look': 4193,
#  'fun': 3030,
#  'mtalk': 4624,
#  '69866': 591,
#  '30pp': 432,
#  '5free': 555,
#  'increments': 3651,
#  'help08718728876': 3400,
#  'av': 1154,
#  'number': 4860,
#  'wil': 7511,
#  'ta': 6671,
#  'nope': 4818,
#  'bored': 1439,
#  'could': 2023,
#  'half': 3299,
#  '8th': 719,
#  'cps': 2040,
#  'causing': 1688,
#  'outages': 5015,
#  'conserve': 1965,
#  'energy': 2579,
#  'famamus': 2752,
#  'did': 2298,
#  'recently': 5621,
#  'thts': 6874,
#  'gift': 3123,
#  'humans': 3541,
#  'hav': 3350,
#  'natural': 4707,
#  'themob': 6815,
#  'link': 4129,
#  'premium': 5381,
#  'pink': 5222,
#  'panther': 5072,
#  'game': 3056,
#  'sugababes': 6579,
#  'zebra': 7728,
#  'animation': 962,
#  'badass': 1199,
#  'hoody': 3478,
#  'wallpaper': 7362,
#  'men': 4444,
#  'shorter': 6115,
#  'ladies': 3993,
#  'gaze': 3080,
#  'eyes': 2725,
#  'probably': 5423,
#  'swing': 6654,
#  'roommate': 5814,
#  'finishes': 2848,
#  'baby': 1191,
#  'taste': 6708,
#  'real': 5592,
#  'veggie': 7259,
#  'pizza': 5229,
#  'whats': 7472,
#  'name': 4684,
#  'taking': 6690,
#  'wonderful': 7575,
#  'okors': 4922,
#  'month': 4576,
#  'cherish': 1763,
#  'wish': 7539,
#  'mojibiola': 4561,
#  'hours': 3509,
#  'da': 2132,
#  'pocked': 5280,
#  'planning': 5241,
#  '7250i': 611,
#  'auction': 1139,
#  'part': 5093,
#  '86021': 681,
#  'hg': 3419,
#  'suite342': 6585,
#  '2lands': 399,
#  'row': 5824,
#  'w1jhl': 7335,
#  'news': 4763,
#  'freefone': 2977,
#  '08006344447': 57,
#  'claim': 1816,
#  'guaranteed': 3260,
#  'cash': 1673,
#  '2000': 352,
#  'speak': 6365,
#  'operator': 4964,
#  'goodmorning': 3182,
#  'late': 4025,
#  'decimal': 2199,
#  'ft': 3015,
#  'combination': 1899,
#  'ooooooh': 4955,
#  'yoville': 7713,
#  'need': 4727,
#  'outsider': 5024,
#  'test': 6774,
#  'earlier': 2497,
#  'appreciate': 1026,
#  'crab': 2044,
#  'running': 5852,
#  'sea': 5959,
#  'shore': 6110,
#  'waves': 7407,
#  'came': 1624,
#  'cleared': 1830,
#  'footprints': 2924,
#  'frnd': 3000,
#  'clearing': 1832,
#  'beautiful': 1280,
#  'replied': 5705,
#  'fox': 2958,
#  'catch': 1682,
#  'off': 4894,
#  'frndsship': 3004,
#  'never': 4756,
#  'lets': 4083,
#  'dwn': 2491,
#  'freemsg': 2979,
#  '250': 373,
#  '84025': 669,
#  'web2mobile': 7422,
#  'mates': 4384,
#  'etc': 2638,
#  'join': 3835,
#  'txt250': 7092,
#  '50p': 541,
#  'box139': 1457,
#  'la32wu': 3987,
#  'txtx': 7101,
#  'plz': 5266,
#  'ans': 976,
#  'bslvyl': 1534,
#  'sent': 6012,
#  'via': 7271,
#  'fullonsms': 3028,
#  'knows': 3959,
#  'wants': 7376,
#  'lot': 4211,
#  'sickness': 6147,
#  'round': 5821,
#  'easy': 2508,
#  'feel': 2789,
#  'soon': 6325,
#  'lol': 4182,
#  'many': 4350,
#  'talents': 6692,
#  'dinner': 2328,
#  'specific': 6371,
#  'regards': 5656,
#  'jaklin': 3779,
#  'idk': 3591,
#  'fuck': 3016,
#  'woke': 7567,
#  'yeesh': 7679,
#  'fall': 2747,
#  'til': 6889,
#  'smart': 6241,
#  '200': 351,
#  'quiz': 5529,
#  'play': 5245,
#  '85222': 678,
#  'cs': 2085,
#  'winnersclub': 7530,
#  '84': 668,
#  'm26': 4277,
#  '3uz': 468,
#  'gbp1': 3082,
#  'evo': 2670,
#  'download': 2422,
#  'flash': 2873,
#  'jealous': 3802,
#  'stitch': 6484,
#  'trouser': 7043,
#  'sec': 5964,
#  'somebody': 6300,
#  'honestly': 3470,
#  'made': 4302,
#  'cup': 2108,
#  'tea': 6725,
#  'promptly': 5453,
#  'dropped': 2454,
#  'keys': 3917,
#  'burnt': 1569,
#  'fingers': 2844,
#  '10': 262,
#  'missed': 4510,
#  'cause': 1687,
#  'yelling': 7681,
#  'scrappy': 5944,
#  'lonely': 4188,
#  'imagine': 3615,
#  'gentle': 3099,
#  'unlike': 7166,
#  'docs': 2379,
#  'treat': 7027,
#  'their': 6810,
#  'patients': 5112,
#  'turkeys': 7074,
#  'guess': 3265,
#  'secretly': 5970,
#  'fancies': 2757,
#  'find': 2839,
#  '09065394973': 227,
#  'landline': 4005,
#  'datebox1282essexcm61xn': 2167,
#  'haf': 3290,
#  'combine': 1900,
#  'din': 2323,
#  'jus': 3870,
#  '420': 483,
#  'private': 5417,
#  '2003': 353,
#  'account': 779,
#  'statement': 6455,
#  'shows': 6132,
#  '800': 633,
#  'un': 7126,
#  'redeemed': 5640,
#  'points': 5288,
#  '08719899230': 163,
#  'identifier': 3588,
#  '41685': 481,
#  'expires': 2710,
#  '07': 21,
#  '11': 275,
#  '04': 15,
#  'actually': 800,
#  'putting': 5505,
#  'ad': 801,
#  'fucks': 3021,
#  'sake': 5874,
#  'daddy': 2137,
#  'care': 1651,
#  'chikku': 1777,
#  'tke': 6909,
#  'bf': 1344,
#  'hello': 3394,
#  'lou': 4219,
#  'mobile': 4543,
#  'friends': 2995,
#  'lancaster': 4002,
#  'bak': 1207,
#  'neway': 4760,
#  'couldn': 2025,
#  'hun': 3542,
#  'about': 753,
#  'cos': 2013,
#  'nighters': 4779,
#  'persevered': 5163,
#  'cheap': 1744,
#  'apologise': 1012,
#  'advance': 829,
#  'somewhere': 6313,
#  'isnt': 3749,
#  ...}

# %%
# To see where is non zero values of a vector
X_train_np = X_train_cv.toarray()
X_train_np[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(7738,))

# %%
np.where(X_train_np[0] != 0)
# Out:
# (array([2479, 2913, 4844, 5204, 7181, 7197]),)

# %%
X_train[:4][2392]
# Out:
# 'PICK UR FONE UP NOW U DUMB?'

# %%
X_train_np[0][2479]
# Out:
# np.int64(1)

# %% [markdown]
# <h3>Train the naive bayes model</h3>

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train_cv, y_train)
# Out:
# MultinomialNB()

# %%
# transform x_test
X_test_cv = v.transform(X_test)

# %% [markdown]
# <h3>Evaluate Performance</h3>

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test_cv)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       987
#            1       0.98      0.91      0.94       128
#
#     accuracy                           0.99      1115
#    macro avg       0.99      0.95      0.97      1115
# weighted avg       0.99      0.99      0.99      1115

# %%
emails = [
    'Hey mohan, can we get together to watch footbal game tomorrow?',
    'Upto 20% discount on parking, exclusive offer just for you. Dont miss this reward!'
]

emails_count = v.transform(emails)
model.predict(emails_count)
# Out:
# array([0, 1])

# %% [markdown]
# <h3>Train the model using sklearn pipeline and reduce number of lines of code</h3>

# %%
from sklearn.pipeline import Pipeline

clf = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('nb', MultinomialNB())
])

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()), ('nb', MultinomialNB())])

# %%
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       987
#            1       0.98      0.91      0.94       128
#
#     accuracy                           0.99      1115
#    macro avg       0.99      0.95      0.97      1115
# weighted avg       0.99      0.99      0.99      1115
